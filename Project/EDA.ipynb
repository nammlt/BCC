# %% [markdown]
# # EDA

# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\fanss\OneDrive\Documents\Brain Code Camp\ds003458\Project

# %%
df = pd.read_excel(r'C:\Users\fanss\OneDrive\Documents\Brain Code Camp\ds003458\code\Bandit Tracking _ For Upload.xlsx')
df
# Out:
#      ID  Perform  Peripherals  EMG OK  SCR OK  Bandit Duration  Sex  Age
# 0   102        1            0       0       0             24.0    1   20
# 1   103        1            0       0       0             28.0    2   18
# 2   201        1            0       0       0             29.0    1   20
# 3   208        1            1       1       1             27.0    2   18
# 4   209        1            1       0       1             50.0    2   21
# 5   210        1            1       1       1              NaN    2   19
# 6   213        1            1       1       1             36.0    2   19
# 7   214        1            1       1       1             37.0    2   20
# 8   215        1            0       0       0             40.0    1   19
# 9   216        1            1       1       1             53.0    2   21
# 10  220        1            1       0       0             50.0    2   19
# 11  221        1            1       1       1             35.0    2   19
# ...

# %% [markdown]
# - Sex

# %%
gender_counts = df['Sex'].value_counts()
print(f"Male: {gender_counts[1]}")
print(f"Female: {gender_counts[2]}")
# Out:
# Male: 7
# Female: 16

# %% [markdown]
# - Age

# %%
min_age = df['Age'].min()
max_age = df['Age'].max()
average_age = df['Age'].mean()

# %%
print(f"Min Age: {min_age}")
print(f"Max Age: {max_age}")
print(f"Avg Age: {round(average_age, 2)}")
# Out:
# Min Age: 18
# Max Age: 24
# Avg Age: 19.96
